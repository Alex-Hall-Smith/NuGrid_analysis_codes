# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator
# %matplotlib inline

# %%
ZtoSym = {0:'Nn', 1:'H', 2:'He', 3:'Li', 4:'Be', 5:'B', 6:'C', 7:'N', 8:'O', 9:'F',
10:'Ne', 11:'Na', 12:'Mg', 13:'Al', 14:'Si', 15:'P', 16:'S', 17:'Cl', 18:'Ar',
19:'K', 20:'Ca', 21:'Sc', 22:'Ti', 23:'V', 24:'Cr', 25:'Mn', 26:'Fe', 27:'Co',
28:'Ni', 29:'Cu', 30:'Zn', 31:'Ga', 32:'Ge', 33:'As', 34:'Se', 35:'Br', 36:'Kr',
37:'Rb', 38:'Sr', 39:'Y', 40:'Zr', 41:'Nb', 42:'Mo', 43:'Tc', 44:'Ru', 45:'Rh',
46:'Pd', 47:'Ag', 48:'Cd', 49:'In', 50:'Sn', 51:'Sb', 52:'Te', 53:'I', 54:'Xe',
55:'Cs', 56:'Ba', 57:'La', 58:'Ce', 59:'Pr', 60:'Nd', 61:'Pm', 62:'Sm', 63:'Eu',
64:'Gd', 65:'Tb', 66:'Dy', 67:'Ho', 68:'Er', 69:'Tm', 70:'Yb', 71:'Lu', 72:'Hf',
73:'Ta', 74:'W', 75:'Re', 76:'Os', 77:'Ir', 78:'Pt', 79:'Au', 80:'Hg', 81:'Tl',
82:'Pb', 83:'Bi', 84:'Po', 85:'At', 86:'Rn', 87:'Fr', 88:'Ra', 89:'Ac', 90:'Th',
91:'Pa', 92:'U', 93:'Np', 94:'Pu', 95:'Am', 96:'Cm', 97:'Bk', 98:'Cf', 99:'Es',
100:'Fm', 101:'Md', 102:'No', 103:'Lr', 104:'Rf', 105:'Db', 106:'Sg', 107:'Bh',
108:'Hs', 109:'Mt', 110:'Ds', 111:'Rg', 112:'Cn', 113:'Nh', 114:'Fl', 115:'Mc',
116:'Lv', 117:'Ts', 118:'Og', 119:'Ze', 120:'Zf', 121:'Zg', 122:'Zh', 123:'Zi',
124:'Zj', 125:'Zk', 126:'Zl', 127:'Zm', 128:'Yn', 129:'Zo', 130:'Zp', 131:'Zq',
132:'Yr', 133:'Zs', 134:'Zt', 135:'Zu', 136:'Zv', 137:'Zw', 138:'Zx', 139:'Zy',
140:'Zz'}

SymtoZ = {value: key for key, value in ZtoSym.items()}

def ZtoSymbol(Z):
    if Z in ZtoSym:
        return ZtoSym[Z]
    else:
        return f"No conversion found for {Z}"

def SymboltoZ(element):
    element_lower = re.sub(r'\d', '', element.strip().lower())
    for number, symbol in ZtoSym.items():
        if len(element.strip()) == 1:
            if element.strip() == 'p':
                return '1'
            if element.strip() == 'd':
                return '1'
            if element.strip() == 't':
                return '1'
            if element.strip() == 'n':
                return '0'
          
    for number, symbol in ZtoSym.items():
        if symbol.lower() == element_lower:
            return number
        elif element_lower == 'al-':
            return '13'
        elif element_lower == 'al*':
            return '13'
    return None

# %% [markdown]
# # Code comparison Data entry

# %%
# Simple Trajectory
Nugrid = '/shared/storage/physnp/ahs539/Nugrid/NuPPN/frames/ppn/Reaction_Library_Tests/PPN_no_vital/Simple/No_Vital_No_NACRE_No_ILI01/iso_massf00030.DAT'
PRISM = '/shared/storage/physnp/ahs539/Comparison_paper_figures_Sept_2025/iso_massf_Simple_PRISM.DAT'
Nucleo = '/shared/storage/physnp/ahs539/Comparison_paper_figures_Sept_2025/Nucelo_simple.dat'
Skynet = '/shared/storage/physnp/ahs539/skynet/examples/code_tests/simple_H_burn_update_net/Final_data/S_DB_scr_noHeat.h5.dat'
skynet =  np.genfromtxt(Skynet, skip_header = 249, dtype=None, usecols = (0, 1, 2, 3, 4, 5), encoding=None)

# %%
# XRB
Nugrid = '/shared/storage/physnp/ahs539/Nugrid/NuPPN/frames/ppn/Reaction_Library_Tests/PPN_no_vital/XRB/No_Vital_No_NACRE_No_ILI01/iso_massf02389.DAT'
PRISM = '/shared/storage/physnp/ahs539/Comparison_paper_figures_Sept_2025/iso_massf_XRB_PRISM.DAT'
Nucleo = '/shared/storage/physnp/ahs539/Comparison_paper_figures_Sept_2025/Nucelo_XRB.dat'
Skynet = '/shared/storage/physnp/ahs539/skynet/examples/code_tests/X-ray_update_net/S_DB_scr_noHeat.h5.dat'
skynet =  np.genfromtxt(Skynet, skip_header = 1556, dtype=None, usecols = (0, 1, 2, 3, 4, 5), encoding=None)

# %%
# Weak-s
Nugrid = '/shared/storage/physnp/ahs539/Nugrid/NuPPN/frames/ppn/Reaction_Library_Tests/PPN_no_vital/Weak-s/No_Vital_No_NACRE_No_ILI01/iso_massf01597.DAT'
PRISM = 'prism1.6.0.zip_New/prism1.6.0_data_package/input/All_runs_Reaclib_Default_24062021/Weak_s-process/Output_only_Rlib/x.txt'
Skynet = '/shared/storage/physnp/ahs539/skynet/examples/code_tests/Weak-s_update-net/S_DB_scr_noHeat.h5.dat'
skynet =  np.genfromtxt(Skynet, skip_header = 757, dtype=None, usecols = (0, 1, 2, 3, 4, 5), encoding=None)

# %%
nugrid =  np.genfromtxt(Nugrid, skip_header = 7, dtype=None, usecols = (0, 1, 2, 3, 4, 5), encoding=None)
prism =  np.genfromtxt(PRISM, skip_header = 7, dtype=None, usecols = (0, 1, 2, 3, 4, 5), encoding=None)
nucleo =  np.genfromtxt(Nucleo, skip_header = 7, dtype=None, usecols = (0, 1, 2, 3, 4, 5), encoding=None)

# %%
print(skynet[0])
total = 0
for i in skynet:
    total = total + i[4]
print(total)
tot = 0
k = 1
for j in skynet:
    k = k+1
    j[4] = (j[4]/total)
    tot = tot + j[4]
print(skynet[0][4])
print(tot)
# Out:
# (0, 0., 0., 0, 5.58524151e-28, 0.)
# 3.557784266885667
# 1.5698651448423384e-28
# 1.0000000000000009

# %%
temp = []
ele_nugrid =[]
for K in range(84):
    for J in range(len(nugrid)):
        if float(nugrid[J][1]) == K:
            temp.append(float(nugrid[J][4]))
    A = sum(temp)
    ele_nugrid.append(A)
    temp=[]
temp = []
ele_prism =[]
for K in range(84):
    for J in range(len(prism)):
        if float(prism[J][1]) == K:
            temp.append(float(prism[J][4]))
    A = sum(temp)
    ele_prism.append(A)
    temp=[]
temp = []
ele_nucleo =[]
for K in range(84):
    for J in range(len(nucleo)):
        if float(nucleo[J][1]) == K:
            temp.append(float(nucleo[J][4]))
    A = sum(temp)
    ele_nucleo.append(A)
    temp=[]
temp = []
ele_skynet =[]
for K in range(84):
    for J in range(len(skynet)):
        if float(skynet[J][3]) == K:
            temp.append(float(skynet[J][4]))
    A = sum(temp)
    ele_skynet.append(A)
    temp=[]
ele_name = []
ele_num = []
for K in range(84):
    ele_name.append(ZtoSymbol(K))
    ele_num.append(K)

# %%
div_lim = 0.1

Difference = []
Base_a = []
Base_b = []
Base_c = []

per_cent_a = []
per_cent_b = []
per_cent_c = []

Base_name1 = []
Base_name2 = []
for i in range(len(ele_nugrid)):
    A = 0
    B = 0
    C = 0

    if float(ele_nugrid[i]) - float(ele_prism[i]) > 1e-15 or float(ele_nugrid[i]) - float(ele_prism[i]) < -1e-15:
        A = float(ele_prism[i]) - float(ele_nugrid[i])
        Pc_a = float(A/ele_nugrid[i])*100
    else:
        A = float(ele_prism[i]) - float(ele_nugrid[i])
        Pc_a = float(A/ele_nugrid[i])*100
    if float(ele_nugrid[i]) - float(ele_nucleo[i]) > 1e-15 or float(ele_nugrid[i]) - float(ele_nucleo[i]) < -1e-15:
        B = float(ele_nucleo[i]) - float(ele_nugrid[i])
        Pc_b = float(B/ele_nugrid[i])*100
    else: 
        B = float(ele_nucleo[i]) - float(ele_nugrid[i])
        Pc_b = float(B/ele_nugrid[i])*100
    if float(ele_nugrid[i]) - float(ele_skynet[i]) > 1e-15 or float(ele_nugrid[i]) - float(ele_skynet[i]) < -1e-15:
        C = float(ele_skynet[i]) - float(ele_nugrid[i])
        Pc_c = float(C/ele_nugrid[i])*100
    else:
        C = float(ele_skynet[i]) - float(ele_nugrid[i])
        Pc_c = float(C/ele_nugrid[i])*100
    if A != 0 or B != 0 or C != 0:
        Base_name1.append(ele_name[i])
        Base_a.append(A)
        Base_b.append(B)
        Base_c.append(C)
    if  abs(Pc_a) > div_lim or abs(Pc_b) > div_lim or abs(Pc_c) > div_lim or abs(Pc_d) > div_lim or abs(Pc_e) > div_lim:
        Base_name2.append(ele_name[i])
        per_cent_a.append(Pc_a)
        per_cent_b.append(Pc_b)
        per_cent_c.append(Pc_c)

# %%
fig1, ax1 = plt.subplots(1, 1, figsize=(7.5, 5), dpi = 500)
ax1.scatter(Base_name2, per_cent_b, color = 'b', marker = 's', label = 'PRISM') # Old including sups/new only Rlib
ax1.scatter(Base_name2, per_cent_a, color = 'r', marker = 'd', label = 'Nucleo') # New including sups/new only Rlib
ax1.scatter(Base_name2, per_cent_c, color = 'g', marker = '+', label = 'SkyNet') # New no Ili01/new only Rlib

ax1.hlines(0, -1, len(per_cent_a), colors='k')
ax1.xaxis.set_ticks_position('bottom')
ax1.set_title('Code comparison percentage difference in mass fraction')
ax1.set_ylim(-1e5,1e5)
ax1.set_xlim(-1,len(per_cent_a))
ax1.grid()
ax1.legend(fontsize = 5)
ax1.set_ylabel("Percentage difference compared in Mass fraction \n compared to NuGrid")
ax1.set_xlabel("Element")
plt.yscale("symlog", linthresh = div_lim)
plt.show()
# plt.savefig("../Comparison_paper_figures_Sept_2025/" + Title + "percentage_difference.png")

# %%
fig1, ax1 = plt.subplots(1, 1, figsize=(15, 5), dpi = 500)

ax1.plot(ele_num, ele_nugrid, color = 'b', linewidth=2, alpha = 0.5, label = 'NuGrid')
ax1.plot(ele_num, ele_prism, color = 'r', linewidth=2, alpha = 0.5, label = 'PRISM')
ax1.plot(ele_num, ele_nucleo, color = 'm', linewidth=2, alpha = 0.5, label = 'Nucleo')
ax1.plot(ele_num, ele_skynet, color = 'y', linewidth=2, alpha = 0.5, label = 'SkyNet')
ax1.set_yscale('log')
ax1.set_ylim(1e-15, 10)
ax1.set_xlim(-1, 85)
ax1.grid('True')
ax1.legend()
ax1.xaxis.set_major_locator(MultipleLocator(5))
ax1.set_title('Simple H burn elemental abundance code comparison')
plt.show()

# %% [markdown]
# # Library comparison Data entry

# %%
Title = 'Simple hydrostatic burn'
Simp_og = '/shared/storage/physnp/ahs539/Nugrid/nuppn-modular2_ininet3/frames/ppn/Library_tests/og_network_Simple/iso_massf00029.DAT'
Simp_new = '/shared/storage/physnp/ahs539/Nugrid/NuPPN/frames/ppn/Reaction_Library_Tests/PPN_with_VITAL/Simple_og_libs/iso_massf00029.DAT'
Simp_new_no_ili = '/shared/storage/physnp/ahs539/Nugrid/NuPPN/frames/ppn/Reaction_Library_Tests/PPN_with_VITAL/Simple_no_ILI01/iso_massf00029.DAT'
Simp_new_no_nacrr = '/shared/storage/physnp/ahs539/Nugrid/NuPPN/frames/ppn/Reaction_Library_Tests/PPN_with_VITAL/Simple_no_NACRR/iso_massf00029.DAT'
Simp_new_no_vital = '/shared/storage/physnp/ahs539/Nugrid/NuPPN/frames/ppn/Reaction_Library_Tests/PPN_no_vital/Simple/No_Vital/iso_massf00029.DAT'
Simp_new_only_Rlib = '/shared/storage/physnp/ahs539/Nugrid/NuPPN/frames/ppn/Reaction_Library_Tests/PPN_no_vital/Simple/No_Vital_No_NACRE_No_ILI01/iso_massf00030.DAT'

# %%
Title = 'X-ray burst'

Simp_og = '/shared/storage/physnp/ahs539/Nugrid/nuppn-modular2_ininet3/frames/ppn/Library_tests/og_network_XRB/iso_massf02389.DAT'
Simp_new = '/shared/storage/physnp/ahs539/Nugrid/NuPPN/frames/ppn/Reaction_Library_Tests/PPN_with_VITAL/XRB_og_libs/iso_massf02389.DAT'
Simp_new_no_ili = '/shared/storage/physnp/ahs539/Nugrid/NuPPN/frames/ppn/Reaction_Library_Tests/PPN_with_VITAL/XRB_no_ILI01/iso_massf02389.DAT'
Simp_new_no_nacrr = '/shared/storage/physnp/ahs539/Nugrid/NuPPN/frames/ppn/Reaction_Library_Tests/PPN_with_VITAL/XRB_no_NACRR/iso_massf02389.DAT'
Simp_new_no_vital = '/shared/storage/physnp/ahs539/Nugrid/NuPPN/frames/ppn/Reaction_Library_Tests/PPN_no_vital/XRB/No_Vital/iso_massf02389.DAT'
Simp_new_only_Rlib = '/shared/storage/physnp/ahs539/Nugrid/NuPPN/frames/ppn/Reaction_Library_Tests/PPN_no_vital/XRB/No_Vital_No_NACRE_No_ILI01/iso_massf02389.DAT'

# %%
Title = 'Weak S-process'

Simp_og = '/shared/storage/physnp/ahs539/Nugrid/nuppn-modular2_ininet3/frames/ppn/Library_tests/weak-s_og_libs/iso_massf01597.DAT'
Simp_new = '/shared/storage/physnp/ahs539/Nugrid/NuPPN/frames/ppn/Reaction_Library_Tests/PPN_with_VITAL/weak-s_og_libs/iso_massf01597.DAT'
Simp_new_no_ili = '/shared/storage/physnp/ahs539/Nugrid/NuPPN/frames/ppn/Reaction_Library_Tests/PPN_with_VITAL/weak-s_no_ILI01/iso_massf01597.DAT'
Simp_new_no_nacrr = '/shared/storage/physnp/ahs539/Nugrid/NuPPN/frames/ppn/Reaction_Library_Tests/PPN_with_VITAL/weak-s_no_NACRR/iso_massf01597.DAT'
Simp_new_no_vital = '/shared/storage/physnp/ahs539/Nugrid/NuPPN/frames/ppn/Reaction_Library_Tests/PPN_no_vital/Weak-s/No_Vital/iso_massf01597.DAT'
Simp_new_only_Rlib = '/shared/storage/physnp/ahs539/Nugrid/NuPPN/frames/ppn/Reaction_Library_Tests/PPN_no_vital/Weak-s/No_Vital_No_NACRE_No_ILI01/iso_massf01597.DAT'

# %%
Title = 'Common Envelope'

Simp_og = '/shared/storage/physnp/ahs539/Nugrid/nuppn-modular2_ininet3/frames/ppn/Library_tests/og_network_CE_8e-5/iso_massf00335.DAT'
Simp_new = '/shared/storage/physnp/ahs539/Nugrid/NuPPN/frames/ppn/Reaction_Library_Tests/PPN_with_VITAL/CE_8e-5_og_libs/iso_massf00335.DAT'
Simp_new_no_ili = '/shared/storage/physnp/ahs539/Nugrid/NuPPN/frames/ppn/Reaction_Library_Tests/PPN_with_VITAL/CE_8e-5_no_ILI01/iso_massf00335.DAT'
Simp_new_no_nacrr = '/shared/storage/physnp/ahs539/Nugrid/NuPPN/frames/ppn/Reaction_Library_Tests/PPN_with_VITAL/CE_8e-5_no_NACRR/iso_massf00335.DAT'
Simp_new_no_vital = '/shared/storage/physnp/ahs539/Nugrid/NuPPN/frames/ppn/Reaction_Library_Tests/PPN_no_vital/CE_8/No_Vital/iso_massf00335.DAT'
Simp_new_only_Rlib = '/shared/storage/physnp/ahs539/Nugrid/NuPPN/frames/ppn/Reaction_Library_Tests/PPN_no_vital/CE_8/No_Vital_No_NACRE_No_ILI01/iso_massf00335.DAT'

# %%
Simple_o = np.genfromtxt(Simp_og, skip_header = 7, dtype=None, usecols = (0, 1, 2, 3, 4, 5), encoding=None)
Simple_n = np.genfromtxt(Simp_new, skip_header = 7, dtype=None, usecols = (0, 1, 2, 3, 4, 5), encoding=None)
Simple_n_noili = np.genfromtxt(Simp_new_no_ili, skip_header = 7, dtype=None, usecols = (0, 1, 2, 3, 4, 5), encoding=None)
Simple_n_nonacrr = np.genfromtxt(Simp_new_no_nacrr, skip_header = 7, dtype=None, usecols = (0, 1, 2, 3, 4, 5), encoding=None)
Simple_n_nvital = np.genfromtxt(Simp_new_no_vital, skip_header = 7, dtype=None, usecols = (0, 1, 2, 3, 4, 5), encoding=None)
Simple_n_rlib = np.genfromtxt(Simp_new_only_Rlib, skip_header = 7, dtype=None, usecols = (0, 1, 2, 3, 4, 5), encoding=None)

# %%
temp = []
ele_S_og =[]
for K in range(84):
    for J in range(len(Simple_o)):
        if float(Simple_o[J][1]) == K:
            temp.append(float(Simple_o[J][4]))
    A = sum(temp)
    ele_S_og.append(A)
    temp=[]

ele_S_n =[]
for K in range(84):
    for J in range(len(Simple_n)):
        if float(Simple_n[J][1]) == K:
            temp.append(float(Simple_n[J][4]))
    A = sum(temp)
    ele_S_n.append(A)
    temp=[]

ele_S_n_ni =[]
for K in range(84):
    for J in range(len(Simple_n_noili)):
        if float(Simple_n_noili[J][1]) == K:
            temp.append(float(Simple_n_noili[J][4]))
    A = sum(temp)
    ele_S_n_ni.append(A)
    temp=[]

ele_S_n_nn =[]
for K in range(84):
    for J in range(len(Simple_n_nonacrr)):
        if float(Simple_n_nonacrr[J][1]) == K:
            temp.append(float(Simple_n_nonacrr[J][4]))
    A = sum(temp)
    ele_S_n_nn.append(A)
    temp=[]

ele_S_n_nv =[]
for K in range(84):
    for J in range(len(Simple_n_nvital)):
        if float(Simple_n_nvital[J][1]) == K:
            temp.append(float(Simple_n_nvital[J][4]))
    A = sum(temp)
    ele_S_n_nv.append(A)
    temp=[]

ele_S_n_rlib =[]
for K in range(84):
    for J in range(len(Simple_n_rlib)):
        if float(Simple_n_rlib[J][1]) == K:
            temp.append(float(Simple_n_rlib[J][4]))
    A = sum(temp)
    ele_S_n_rlib.append(A)
    temp=[]

# %%
temp = 0
for a in ele_S_n_rlib:
    temp = temp + float(a)
print(temp)
temp = 0
for a in ele_S_og:
    temp = temp + float(a)
print(temp)

print(len(Simp_new_only_Rlib))
print(Simp_new_only_Rlib[-1])
print(len(Simp_new))
print(Simp_new[-1])
# Out:
# 0.9999998898199297
# 1.0000001974469808
# 139
# T
# 122
# T

# %%
ele_name = []
ele_num = []
for K in range(84):
    ele_name.append(ZtoSymbol(K))
    ele_num.append(K)

# %%
div_lim = 0.1

Difference = []
Base_a = []
Base_b = []
Base_c = []
Base_d = []
Base_e = []
per_cent_a = []
per_cent_b = []
per_cent_c = []
per_cent_d = []
per_cent_e = []
Base_name1 = []
Base_name2 = []
for i in range(len(ele_S_n)):
    A = 0
    B = 0
    C = 0
    D = 0
    E = 0
    if float(ele_S_n_rlib[i]) - float(ele_S_n[i]) > 1e-15 or float(ele_S_n_rlib[i]) - float(ele_S_n[i]) < -1e-15:
        A = float(ele_S_n[i]) - float(ele_S_n_rlib[i])
        Pc_a = float(A/ele_S_n_rlib[i])*100
    if float(ele_S_n_rlib[i]) - float(ele_S_og[i]) > 1e-15 or float(ele_S_n_rlib[i]) - float(ele_S_og[i]) < -1e-15:
        B = float(ele_S_og[i]) - float(ele_S_n_rlib[i])
        Pc_b = float(B/ele_S_n_rlib[i])*100
    if float(ele_S_n_rlib[i]) - float(ele_S_n_ni[i]) > 1e-15 or float(ele_S_n_rlib[i]) - float(ele_S_n_ni[i]) < -1e-15:
        C = float(ele_S_n_ni[i]) - float(ele_S_n_rlib[i])
        Pc_c = float(C/ele_S_n_rlib[i])*100
    if float(ele_S_n_rlib[i]) - float(ele_S_n_nn[i]) > 1e-15 or float(ele_S_n_rlib[i]) - float(ele_S_n_nn[i]) < -1e-15:
        D = float(ele_S_n_nn[i]) - float(ele_S_n_rlib[i])
        Pc_d = float(D/ele_S_n_rlib[i])*100
    if float(ele_S_n_rlib[i]) - float(ele_S_n_nv[i]) > 1e-15 or float(ele_S_n_rlib[i]) - float(ele_S_n_nv[i]) < -1e-15:
        E = float(ele_S_n_nv[i]) - float(ele_S_n_rlib[i])
        Pc_e = float(E/ele_S_n_rlib[i])*100
    if A != 0 or B != 0 or C != 0 or D != 0 or E != 0:
        Base_name1.append(ele_name[i])
        Base_a.append(A)
        Base_b.append(B)
        Base_c.append(C)
        Base_d.append(D)
        Base_e.append(E)
    if  abs(Pc_a) > div_lim or abs(Pc_b) > div_lim or abs(Pc_c) > div_lim or abs(Pc_d) > div_lim or abs(Pc_e) > div_lim:
        Base_name2.append(ele_name[i])
        per_cent_a.append(Pc_a)
        per_cent_b.append(Pc_b)
        per_cent_c.append(Pc_c)
        per_cent_d.append(Pc_d)
        per_cent_e.append(Pc_e)
    
        

with open("../Comparison_paper_figures_Sept_2025/" + Title + "_difference.txt", "w") as f:
    for item in Difference:
        f.write(str(item) + "\n")

# %%
fig1, ax1 = plt.subplots(1, 1, figsize=(7.5, 5), dpi = 500)
ax1.scatter(Base_name2, per_cent_b, color = 'b', marker = 's', label = 'Reaclib v1.1 including supplementary libraries') # Old including sups/new only Rlib
ax1.scatter(Base_name2, per_cent_a, color = 'r', marker = 'd', label = 'Reaclib 2021 including supplementary libraries') # New including sups/new only Rlib
ax1.scatter(Base_name2, per_cent_c, color = 'g', marker = '+', label = 'Reaclib 2021 no Iliadis 2001') # New no Ili01/new only Rlib
ax1.scatter(Base_name2, per_cent_d, color = 'y', marker = 'x', label = 'Reaclib 2021 no NACRR') # New no NACRR/new only Rlib
ax1.scatter(Base_name2, per_cent_e, color = 'm', marker = '*', label = 'Reaclib 2021 no Vital') # New no Vital/new only Rlib
# ax1.plot(Base_name, ele_S_n_rlib, color = 'k', alpha = 0.3)
ax1.hlines(0, -1, len(per_cent_a), colors='k')
# ax1.spines['bottom'].set_position('center') # x-axis goes through y=0
# ax1.spines['right'].set_color('none')
# ax1.spines['top'].set_color('none')
ax1.xaxis.set_ticks_position('bottom')
ax1.set_title(Title + '  percentage difference in mass fraction')
ax1.set_ylim(-1e5,1e5)
ax1.set_xlim(-1,len(per_cent_a))
ax1.grid()
ax1.legend(fontsize = 5)
ax1.set_ylabel("Percentage difference in mass fraction compared to NuGrid using only Reaclib 2021")
ax1.set_xlabel("Element")
plt.yscale("symlog", linthresh = div_lim)
# plt.show()
plt.savefig("../Comparison_paper_figures_Sept_2025/" + Title + "percentage_difference.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1920731/1681347717.py in <module>
#       3 ax1.scatter(Base_name2, per_cent_a, color = 'r', marker = 'd', label = 'Reaclib 2021 including supplementary libraries') # New including sups/new only Rlib
#       4 ax1.scatter(Base_name2, per_cent_c, color = 'g', marker = '+', label = 'Reaclib 2021 no Iliadis 2001') # New no Ili01/new only Rlib
# ----> 5 ax1.scatter(Base_name2, per_cent_d, color = 'y', marker = 'x', label = 'Reaclib 2021 no NACRR') # New no NACRR/new only Rlib
#       6 ax1.scatter(Base_name2, per_cent_e, color = 'm', marker = '*', label = 'Reaclib 2021 no Vital') # New no Vital/new only Rlib
#       7 # ax1.plot(Base_name, ele_S_n_rlib, color = 'k', alpha = 0.3)
#
# NameError: name 'per_cent_d' is not defined

# %%
fig1, ax1 = plt.subplots(1, 1, figsize=(10, 7), dpi = 500)
ax1.scatter(Base_name, Base_a, color = 'r')
ax1.scatter(Base_name, Base_b, color = 'b')
ax1.scatter(Base_name, Base_c, color = 'g')
ax1.scatter(Base_name, Base_d, color = 'y')
ax1.scatter(Base_name, Base_e, color = 'm')
ax1.plot(Base_name, ele_S_n_rlib, color = 'k', alpha = 0.3)
ax1.hlines(0, 0, 85, colors='k')
# ax1.spines['bottom'].set_position('center') # x-axis goes through y=0
# ax1.spines['right'].set_color('none')
# ax1.spines['top'].set_color('none')
ax1.xaxis.set_ticks_position('bottom')
ax1.set_title(Title + ' difference in mass fraction')
ax1.set_ylim(-1,1)
ax1.set_xlim(0,85)
ax1.grid()
plt.yscale("symlog", linthresh = 1e-15)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_669123/1283973455.py in <module>
#       1 fig1, ax1 = plt.subplots(1, 1, figsize=(10, 7), dpi = 500)
# ----> 2 ax1.scatter(Base_name, Base_a, color = 'r')
#       3 ax1.scatter(Base_name, Base_b, color = 'b')
#       4 ax1.scatter(Base_name, Base_c, color = 'g')
#       5 ax1.scatter(Base_name, Base_d, color = 'y')
#
# /usr/lib/python3/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1414     def inner(ax, *args, data=None, **kwargs):
#    1415         if data is None:
# -> 1416             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1417
#    1418         bound = new_sig.bind(ax, *args, **kwargs)
#
# ...

# %%
fig1, ax1 = plt.subplots(1, 1, figsize=(15, 5), dpi = 500)

ax1.plot(ele_num, ele_S_og, color = 'b', linewidth=6, alpha = 0.5, label = 'Reaclib v1.1 inc. supplemetary libraries')
ax1.plot(ele_num, ele_S_n, color = 'r', linewidth=5, alpha = 0.5, label = 'Reaclib 2021 inc. supplemetary libraries')
ax1.plot(ele_num, ele_S_n_ni, color = 'm', linewidth=4, alpha = 0.5, label = 'Reaclib 2021 no Iliadis 2001')
ax1.plot(ele_num, ele_S_n_nn, color = 'y', linewidth=3, alpha = 0.5, label = 'Reaclib 2021 no Nacre')
ax1.plot(ele_num, ele_S_n_nv, color = 'g', linewidth=2, alpha = 0.5, label = 'Reaclib 2021 no Vital')
ax1.plot(ele_num, ele_S_n_rlib, color = 'k', linewidth=1, alpha = 0.5, label = 'Only Reaclib 2021')
ax1.set_yscale('log')
ax1.set_ylim(1e-15, 10)
ax1.set_xlim(-1, 85)
ax1.grid('True')
ax1.legend()
ax1.xaxis.set_major_locator(MultipleLocator(5))
ax1.set_title(Title + 'elemental abundances')
plt.show()

# %%
fig1, ax1 = plt.subplots(1, 1, figsize=(10, 5), dpi = 200)

ax1.scatter(ele_num, ele_S_og, marker = 's', s = 35, color = 'k', label = 'Common envelope initial abundance')
ax1.scatter(ele_num, ele_S_n, marker = 'o', s = 30, color = 'r', label = 'Common envelope initial abundance')
ax1.scatter(ele_num, ele_S_n_ni, marker = '*', s = 25, color = 'm', label = 'Common envelope initial abundance')
ax1.scatter(ele_num, ele_S_n_nn, marker = '+', s = 20, color = 'y', label = 'Common envelope initial abundance')
ax1.scatter(ele_num, ele_S_n_nv, marker = 'x', s = 15, color = 'g', label = 'Common envelope initial abundance')
ax1.scatter(ele_num, ele_S_n_rlib, marker = 'D', s = 100, alpha = 0.4, color = 'b', label = 'Common envelope initial abundance')
ax1.set_yscale('log')
ax1.set_ylim(1e-13, 10)
ax1.set_xlim(-1, 25)
ax1.grid('True')
#ax1.legend()
ax1.xaxis.set_major_locator(MultipleLocator(2))
ax1.set_title(Title + ' elemental abundances library comparison')
plt.show()
